# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/jan_2018.csv",index_col=0)
df2 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/feb_2018.csv",index_col=0)
df3 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/mar_2018.csv",index_col=0)
df4 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/apr_2018.csv",index_col=0)
df5 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/may_2018.csv",index_col=0)
df6 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/jun_2018.csv",index_col=0)
df7 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/jul_2018.csv",index_col=0)
df8 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/aug_2018.csv",index_col=0)
df9 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/sep_2018.csv",index_col=0)
df10 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/oct_2018.csv",index_col=0)
df11 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/nov_2018.csv",index_col=0)
df12 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/monthly-data/dec_2018.csv",index_col=0)

# %%
df_1 = pd.concat([df1,df2,df3,df4,df5,df6],axis=0)
df_2 = pd.concat([df7,df8,df9,df10,df11,df12],axis=0)

# %%
df_2
# Out:
#         Unnamed: 0.1 RFDE_CUST_REG_NUM RFDE_RPT_DT   RFDE_TXN_ID  \
# 0                1.0                 5  2018-07-25         64463
# 1                2.0                 5  2018-07-25         64464
# 2                3.0                 5  2018-07-25         64465
# 3                4.0        IN/CUS/023  2018-07-02  0H00000R956M
# 4                5.0        IN/CUS/023  2018-07-02  0H00000R956L
# ...              ...               ...         ...           ...
# 106129           NaN                 6  2019-01-03       1587481
# 106130           NaN                 6  2019-01-03       1587476
# 106131           NaN                 6  2019-01-03       1587473
# 106132           NaN                 6  2019-01-03       1587469
# 106133           NaN                 3  2019-01-03  C00004465617
#
#                    FII         SUB_ACC          BRKER  \
# 0        F548521206073   S640076734501  B617642239091
# 1        F548521206073   S640076734501  B617642239091
# ...

# %%
# Out:
#        RFDE_CUST_REG_NUM RFDE_RPT_DT   RFDE_TXN_ID             FII  \
# 0                      9  2018-01-01     180000314   F694434372708
# 1077                   5  2018-01-02         61537   F513981817122
# 1076                   5  2018-01-02         61550  F1041965594838
# 1075                   5  2018-01-02         61535  F1013807183429
# 1074                   5  2018-01-02         61549  F1106095156084
# ...                  ...         ...           ...             ...
# 128860        IN/CUS/024  2018-07-03        413290  F1124791047670
# 124280                 6  2018-07-02       1560672  F1051193966596
# 127588                 3  2018-07-02  R00000217655   F669183610649
# 128842        IN/CUS/024  2018-07-02     207201801  F1094896472166
# 127909                 3  2018-07-02  R00000217651  F1033832325650
#
#                SUB_ACC          BRKER                         SCRIP_NAME  \
# 0        S476572906396  B769686235185            VAKRANGEE TEMP ISIN DM1
# ...

# %%
#del df_1['Unnamed: 0.1']

# %%
df_1['TR_DATE'] = df_1['TR_DATE'].astype('datetime64[D]')
df_1.sort_values('TR_DATE',inplace=True)
df_1['TR_DATE']
df_1= df_1.reset_index()
del df_1['index']
df_1
# Out:
#        RFDE_CUST_REG_NUM RFDE_RPT_DT   RFDE_TXN_ID             FII  \
# 0                      9  2018-01-01     180000314   F694434372708
# 1                      9  2018-01-01     180000285  F1155223174449
# 2                      9  2018-01-01     180000857   F761086797404
# 3                      9  2018-01-01     180000493   F937768621596
# 4                      9  2018-01-01     180000156   F548406695811
# ...                  ...         ...           ...             ...
# 726567                 3  2018-07-02  R00000217656   F645962415883
# 726568                 3  2018-07-02  R00000217652   F928007698569
# 726569        IN/CUS/024  2018-07-02     207201801  F1094896472166
# 726570        IN/CUS/024  2018-07-02     207201802  F1094896472166
# 726571                 3  2018-07-02  R00000217651  F1033832325650
#
#                SUB_ACC           BRKER                         SCRIP_NAME  \
# 0        S476572906396   B769686235185            VAKRANGEE TEMP ISIN DM1
# ...

# %%
df_2['TR_DATE'] = df_2['TR_DATE'].astype('datetime64[D]')
df_2.sort_values('TR_DATE',inplace=True)
df_2['TR_DATE']
df_2= df_2.reset_index()
del df_2['index']
df_2['TR_DATE']
# Out:
# 0        2018-07-02
# 1        2018-07-02
# 2        2018-07-02
# 3        2018-07-02
# 4        2018-07-02
#             ...
# 680334   2018-12-31
# 680335   2018-12-31
# 680336   2018-12-31
# 680337   2018-12-31
# 680338   2018-12-31
# Name: TR_DATE, Length: 680339, dtype: datetime64[ns]

# %%
#del df_1['BSE_High']
#del df_1['BSE_Low']
#del df_1['BSE_Close']
#del df_1['BSE_Open']
#del df_2['BSE_High']
#del df_2['BSE_Low']
#del df_2['BSE_Close']
#del df_2['BSE_Open']


df_1.to_csv("/Users/garg/Desktop/thesis/data/2018/jan_to_jun_2018.csv")
df_2.to_csv("/Users/garg/Desktop/thesis/data/2018/jul_to_dec_2018.csv")

# %%
import pandas as pd 
df1 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/jul_to_dec_2018.csv",index_col=0)
df1
# Out:
#         Unnamed: 0.1 RFDE_CUST_REG_NUM RFDE_RPT_DT RFDE_TXN_ID  \
# 0             3802.0                 4  2018-07-03    11279431
# 1             3426.0                 4  2018-07-03    11279497
# 2             3425.0                 4  2018-07-03    11277905
# 3             3424.0                 4  2018-07-03    11278377
# 4             3423.0                 4  2018-07-03    11279422
# ...              ...               ...         ...         ...
# 680334           NaN                 9  2019-01-01   190000210
# 680335           NaN                 9  2019-01-01   190000460
# 680336           NaN                 9  2019-01-01   190000415
# 680337           NaN                 9  2019-01-01   190000315
# 680338           NaN                14  2019-01-01     9818817
#
#                    FII         SUB_ACC           BRKER  \
# 0        F577059403378   S921308190267  B1005050980269
# 1        F577059403378   S921308190267  B1005050980269
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0.1          float64
# RFDE_CUST_REG_NUM      object
# RFDE_RPT_DT            object
# RFDE_TXN_ID            object
# FII                    object
# SUB_ACC                object
# BRKER                  object
# SCRIP_NAME             object
# ISIN                   object
# TR_DATE                object
# TR_TYPE(*)              int64
# RFDE_SE_REG_NUM         int64
# RFDE_STLD_CODE         object
# RATE                  float64
# QUANTITY              float64
# VALUE (in Rs)         float64
# RFDE_INSTR_TYPE        object
# RFDE_REASON_DLAY       object
# RFDE_RPT_TYPE          object
# RFDE_AMDMNT_REASON     object
# dtype: object

# %%
df2 = pd.read_csv("/Users/garg/Desktop/thesis/data/2018/jan_to_jun_2018.csv",index_col = 0)
df2.dtypes
# Out:
# RFDE_CUST_REG_NUM      object
# RFDE_RPT_DT            object
# RFDE_TXN_ID            object
# FII                    object
# SUB_ACC                object
# BRKER                  object
# SCRIP_NAME             object
# ISIN                   object
# TR_DATE                object
# TR_TYPE(*)              int64
# RFDE_SE_REG_NUM         int64
# RFDE_STLD_CODE         object
# RATE                  float64
# QUANTITY              float64
# VALUE (in Rs)         float64
# RFDE_INSTR_TYPE        object
# RFDE_REASON_DLAY       object
# RFDE_RPT_TYPE          object
# RFDE_AMDMNT_REASON     object
# Unnamed: 0.1          float64
# dtype: object

# %%
df2.dtypes
# Out:
# RFDE_CUST_REG_NUM      object
# RFDE_RPT_DT            object
# RFDE_TXN_ID            object
# FII                    object
# SUB_ACC                object
# BRKER                  object
# SCRIP_NAME             object
# ISIN                   object
# TR_DATE                object
# TR_TYPE(*)              int64
# RFDE_SE_REG_NUM         int64
# RFDE_STLD_CODE         object
# RATE                  float64
# QUANTITY              float64
# VALUE (in Rs)         float64
# RFDE_INSTR_TYPE        object
# RFDE_REASON_DLAY       object
# RFDE_RPT_TYPE          object
# RFDE_AMDMNT_REASON     object
# foreign-exchange      float64
# Year-Month             object
# Inflation-Rate        float64
# FDI-Inward            float64
# Year                    int64
# FDI-Growth-Rate       float64
# GDP-Growth-Rate       float64
# IIP                   float64
# unemployment-rate     float64
# BSE_Close             float64
# twitter-sentiment     float64
# Real-GDP              float64
# ...

# %%
df = pd.concat([df1,df2],axis=0)
# Out:
#        RFDE_CUST_REG_NUM RFDE_RPT_DT RFDE_TXN_ID             FII  \
# 0             IN/CUS/017  2019-07-08      160974   F491029387846
# 1             IN/CUS/017  2019-07-11      161102   F491029387846
# 2                      4  2019-07-29    12231499   F899434863545
# 3                      5  2019-07-25       68502   F386425501145
# 4                      5  2019-07-25       68503  F1116618140758
# ...                  ...         ...         ...             ...
# 105647                 9  2020-01-02   200000341   F767816923125
# 105648                 9  2020-01-02   200000337   F661910913353
# 105649                 9  2020-01-02   200000352   F494262567965
# 105650        IN/CUS/017  2020-01-02      167491   F576757490024
# 105651                 9  2020-01-03   200000653   F666875257561
#
#                SUB_ACC           BRKER  \
# 0        S329538999481  B1089029408191
# 1        S329538999481  B1089029408191
# 2        S890428512304   B497892661533
# ...

# %%
df['TR_DATE'] = df['TR_DATE'].astype('datetime64[D]')
# Out:
# 0        2019-07-05
# 1        2019-07-10
# 2        2019-07-26
# 3        2019-07-24
# 4        2019-07-24
#             ...
# 105647   2019-12-31
# 105648   2019-12-31
# 105649   2019-12-31
# 105650   2019-12-30
# 105651   2019-12-31
# Name: TR_DATE, Length: 663349, dtype: datetime64[ns]

# %%
df = df.sort_values('TR_DATE')

# %%
df['TR_DATE'].unique()
# Out:
# array(['2019-07-01T00:00:00.000000000', '2019-07-02T00:00:00.000000000',
#        '2019-07-03T00:00:00.000000000', '2019-07-04T00:00:00.000000000',
#        '2019-07-05T00:00:00.000000000', '2019-07-08T00:00:00.000000000',
#        '2019-07-09T00:00:00.000000000', '2019-07-10T00:00:00.000000000',
#        '2019-07-11T00:00:00.000000000', '2019-07-12T00:00:00.000000000',
#        '2019-07-15T00:00:00.000000000', '2019-07-16T00:00:00.000000000',
#        '2019-07-17T00:00:00.000000000', '2019-07-18T00:00:00.000000000',
#        '2019-07-19T00:00:00.000000000', '2019-07-22T00:00:00.000000000',
#        '2019-07-23T00:00:00.000000000', '2019-07-24T00:00:00.000000000',
#        '2019-07-25T00:00:00.000000000', '2019-07-26T00:00:00.000000000',
#        '2019-07-29T00:00:00.000000000', '2019-07-30T00:00:00.000000000',
#        '2019-07-31T00:00:00.000000000', '2019-08-01T00:00:00.000000000',
#        '2019-08-02T00:00:00.000000000', '2019-08-03T00:00:00.000000000',
# ...

# %%
df.to_csv("/Users/garg/Desktop/thesis/data/2019/jul_to_dec_2019.csv")
